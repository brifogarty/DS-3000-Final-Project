# %% [markdown]
# # Web Crawler: [spotifycharts.com](https://spotifycharts.com/)
# ## Contents:
# **0. [Imports](#0.-Imports)**
# **1. [Helper Methods](#1.-Helper-Methods)**
# **2. [Chart Crawling and Scraping Methods](#2.-Chart-Crawling-and-Scraping-Methods)**
# **3. [Method Call](#3.-Method-Call)**
# **4. [Testing](#4.-Testing)**

# %% [markdown]
# ---
# ## 0. Imports

# %%
from bs4 import BeautifulSoup
import http.client
import urllib
import os

import pandas as pd
import numpy as np
import csv

import dateutil.parser
import datetime
import sys

# %% [markdown]
# ---
# ## 1. Helper Methods

# %%
def det_trend_type(trend_fill:str) -> str:
    """Returns the trend type given the fill color of the Spotify Chart trend SVG."""
    # i. color: green; shape: up-triangle
    if trend_fill == '#84bd00':
        return 'Up'
    # ii. color: gray; shape: horizontal-rectangle
    elif trend_fill == '#3e3e40':
        return 'Flat'
    # iii. color: red; shape: down-triangle
    elif trend_fill == '#bd3200':
        return 'Down'
    # iv. color: blue; shape: circle
    elif trend_fill == '#4687d7':
        return 'New'
    # v. unhandled: non-v.1.1 tend_fill
    else:
        return 'UNKNOWN'

# %%
def get_datestamp_str(date):
    """Returns the current datestamp as a string in YY-MM-DD format."""
    datestamp_str = date.strftime('%Y-%m-%d')
    return datestamp_str

# %%
def get_timestamp_str():
    """Returns the current timestamp as a string in YY-MM-DD HH-SS-FF format."""
    now_datetime = datetime.datetime.now()
    timestamp_str = now_datetime.strftime('D-%Y-%m-%d_T-%H-%M-%S-%f')
    return timestamp_str

# %%
def get_soup(url):
    """Returns the BeautifulSoup object for the given URL."""
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    url_req = urllib.request.Request(url, headers = {'User-Agent': user_agent})
    req_resp = urllib.request.urlopen(url_req)
    req_read = req_resp.read()
    req_resp.close()
    return BeautifulSoup(req_read)

# %%
def scrape_region_dict(chart_type_url):
    """Returns a dictionary of region abbreviation keys and region name values."""
    chart_soup = get_soup(chart_type_url)
    region_li_tags = chart_soup.find('div', 
                                     attrs={'class':'responsive-select','data-type':'country'}).find_all('li')
    region_dict = {}
    for li_tag in region_li_tags:
        region_abrv = li_tag.get('data-value').strip()
        region_name = li_tag.get_text()
        region_dict[region_abrv] = region_name
    
    return region_dict

# %%
def scrape_charts_dates(region_url, strt_date_arg, end_date_arg):
    """Returns a list of date strings representing the available charts."""
    region_soup = get_soup(region_url)
    date_div = region_soup.find('div', attrs={'class':'responsive-select','data-type':'date'})
    
    if date_div is None:
        return np.array([], dtype=datetime.date)
    
    else:
        date_li_tags = date_div.find_all('li')
        
        first_li_tag = date_li_tags[0]
        first_li_date = dateutil.parser.isoparse(first_li_tag.get('data-value').strip()).date()
        max_date = first_li_date if end_date_arg is None else end_date_arg

        last_li_tag = date_li_tags[-1]
        last_li_date = dateutil.parser.isoparse(last_li_tag.get('data-value').strip()).date()
        min_date = last_li_date if strt_date_arg is None else strt_date_arg
        
        num_days_delta = (max_date - min_date).days
        date_range_list = [min_date + datetime.timedelta(days=x) for x in range(num_days_delta + 1)]
    
        return date_range_list

# %%
def handle_error(chart_date, chart_region_abrv, chart_name, idx , chart_date_url, error_code):
    """Returns a list of and out prints error details."""
    print('ERROR  : ',  'attempt ', idx, ' ; ', error_code)
    print('         ', chart_date, ' - ', chart_region_abrv, ' - ', chart_name, ' - ', chart_date_url)
    return [chart_name, chart_region_abrv, chart_date, chart_date_url, idx, str(error_code)]

# %%
def gen_csv_filepath(type_str, now_timestamp, start_datestamp, end_datestamp):
    dir_path = './data'
    if not os.path.exists(dir_path): os.mkdir(dir_path)
    
    file_name = type_str + now_timestamp + '_FrmD-' + start_datestamp + '_ToD-' + end_datestamp + '.csv'
    file_path = os.path.join(dir_path, file_name)
    
    return file_path

# %%
def gen_analysis_report(result_df_arg, error_df_arg):
    """Prints analysis metrics for the chart crawl."""
    print('\nRESULT ANALYSIS')
    
    result_analysis_dict = {
        'Num Rows' : result_df_arg.shape[0],
        'Num Cols' : result_df_arg.shape[1],
        'Num Unique Dates' : len(result_df_arg['Date'].unique()),
        'Num Unique Charts' : len(result_df_arg['Chart'].unique()),
        'Num Unique Regions' : len(result_df_arg['Region'].unique()),
        'Num Unique Positions' : len(result_df_arg['Position'].unique()),
        'Num Unique Trends' : len(result_df_arg['Trend'].unique()),
        'Num Unique Titles' : len(result_df_arg['Title'].unique()),
        'Num Unique Artists' : len(result_df_arg['Artist'].unique()),
        'Num Unique Icon_URLs' : len(result_df_arg['Icon_URL'].unique()),
        'Num Unique Spotify_URLs' : len(result_df_arg['Spotify_URL'].unique())
    }
    
    result_analysis_df = pd.DataFrame(data=list(result_analysis_dict.values()), columns=['Value'])
    result_analysis_df['Metric'] = list(result_analysis_dict.keys())
    result_analysis_df.set_index('Metric', inplace=True)
    
    rows_equals_dates = (result_analysis_dict['Num Rows'] 
                         == result_analysis_dict['Num Unique Dates']*200)
    titles_equals_urls = (result_analysis_dict['Num Unique Titles'] 
                          == result_analysis_dict['Num Unique Spotify_URLs'])
    
    min_date = result_df_arg['Date'].min()
    max_date = result_df_arg['Date'].max()
    delta_days = (max_date - min_date).days
    date_equals_delta = (len(result_df_arg['Date'].unique()) == delta_days)

    print('\n-----\n')
    print('RESULTS:\n')
    print(result_analysis_df)
    print('\nNum Rows==Dates?')
    print(' – YES' if rows_equals_dates else ' – NO: ' + str(result_analysis_dict['Num Rows']) 
          + ' ≠ ' + str(result_analysis_dict['Num Unique Dates']*200) 
          + ' = ' + str(result_analysis_dict['Num Unique Dates']) + ' * 200')
    print('\nNum Titles==Spotify_URLs?')
    print(' – YES' if titles_equals_urls else ' – NO: '+ str(result_analysis_dict['Num Unique Titles']) 
          + ' ≠ ' + str(result_analysis_dict['Num Unique Spotify_URLs']))
    print('\nNum Dates==Date Delta?')
    print(' – YES' if date_equals_delta else ' – NO: '+ str(len(result_df_arg['Date'].unique())) 
          + ' ≠ ' + str(delta_days))

    
    # Error Col Names:
    # 'Chart', 'Region', 'Date', 'Chart URL', 'Attempt', 'Error'
    
    incomp_read_df = error_df_arg[error_df_arg['Error'].str.startswith('IncompleteRead')]
    http_df = error_df_arg[error_df_arg['Error'].str.startswith('HTTP Error')]
    skipped_df = error_df_arg[error_df_arg['Attempt']==-1]
    combined_df = (error_df_arg['Error'].str.startswith('IncompleteRead', na=True) | 
                   error_df_arg['Error'].str.startswith('HTTP Error', na=True))
    
    error_analysis_dict = {
        'Num IncompleteRead' : len(incomp_read_df),
        'Num HTTP' : len(http_df),
        'Num Other' : combined_df[combined_df==False].count(),
        'Num Total Errors' : len(error_df_arg),
    }
    
    error_analysis_df = pd.DataFrame(data=list(error_analysis_dict.values()), columns=['Value'])
    error_analysis_df['Metric'] = list(error_analysis_dict.keys())
    error_analysis_df.set_index('Metric', inplace=True)
    
    http_equals_skips = (error_analysis_dict['Num HTTP'] == len(skipped_df))
    
    error_sum = (error_analysis_dict['Num IncompleteRead'] 
                 + error_analysis_dict['Num HTTP'] 
                 + error_analysis_dict['Num Other'])
    
    total_equals_sum = error_analysis_dict['Num Total Errors'] == error_sum
    
    print('\n-----\n')
    print('ERRORS:\n')
    print(error_analysis_df)
    print('\nNum HTTP==Skips?')
    print(' – YES' if http_equals_skips else ' – NO: ' + str(error_analysis_dict['Num HTTP']) 
          + ' ≠ ' + str(len(skipped_df)))
    print('\nNum Total==Sum?')
    print(' – YES' if total_equals_sum else ' – NO: '+ str(error_analysis_dict['Num Total Errors']) 
          + ' ≠ ' + str(error_sum)
          + ' = (' + str(error_analysis_dict['Num IncompleteRead']) 
          + ' + ' + str(error_analysis_dict['Num HTTP']) 
          + ' + ' + str(error_analysis_dict['Num Other']) + ' )')
    print('\nMin date:', min_date)
    print('Max date:', max_date)
    print('\nSKIPPED CHARTS:\n')
    print('\n')
    print(skipped_df)

# %% [markdown]
# ---
# ## 2. Chart Crawling and Scraping Methods

# %%
def scrape_chart(date_soup, chart_name, chart_region, chart_date):
    """Returns pd/DataFrame of data scraped from each chart URL's <table class="chart-table" ...> tag"""
    tr_tags = date_soup.find('table', class_='chart-table').find('tbody').find_all('tr')
    chart_data = []
    
    for tr_tag in tr_tags:
        
        song_info = []
        
        # 0. col1, col2, col3: Chart Name, Chart Region, and Chart Date
        song_info.append(chart_name)
        song_info.append(chart_region)
        song_info.append(chart_date)
        
        # 1. col4: Chart Position; element of {1, 2, ... , 200}
        pos_tag = tr_tag.find('td', class_='chart-table-position')
        pos_val = int(pos_tag.get_text().strip())
        song_info.append(pos_val)
        
        # 2. col5: Streaming Trend Type; element of {Up, Flat, Down, New}
        trend_tag = tr_tag.find('td', class_='chart-table-trend')
        trend_fill = trend_tag.find('svg').get('fill').strip()
        trend_val = det_trend_type(trend_fill)
        song_info.append(trend_val)
        
        # 3. col6, col7: Track Title and Artist
        track_tag = tr_tag.find('td', class_='chart-table-track')
        title_val = track_tag.find('strong').get_text().strip()
        artist_val = track_tag.find('span').get_text().strip().replace('by ', '')
        song_info.append(title_val)
        song_info.append(artist_val)
        
        # 4. col8: Total Daily Streams
        if chart_name == 'Viral50':
            song_info.append(None)
        else:
            streams_tag = tr_tag.find('td', class_='chart-table-streams')
            streams_val = int(streams_tag.get_text().strip().replace(',',''))
            song_info.append(streams_val)
        
        # 5. col9, col10: Icon and Spotify URLs
        icon_tag = tr_tag.find('td', class_='chart-table-image')
        icon_url_val = icon_tag.find('img').get('src').strip()
        spotify_url_val = icon_tag.find('a').get('href').strip()
        song_info.append(icon_url_val)
        song_info.append(spotify_url_val)
        
        #6. col11: Spotify ID
        spotify_id_val = spotify_url_val[(spotify_url_val.rfind('/') + 1):].strip()
        song_info.append(spotify_id_val)
        
        chart_data.append(song_info)

    return chart_data

# %%
def crawl_spotify_charts(start_date=None,
                         end_date=None,
                         select_regions_dict=None,
                         crawl_top=False,
                         crawl_viral=False,
                         crawl_daily=False,
                         crawl_weekly=False,
                         colab_save=False):
    """Returns a pd.DataFrame containing information scraped from https://spotifycharts.com."""
    # 1. loop through charts
    base_url = 'https://spotifycharts.com'
    
    chart_type_dict = dict()
    if crawl_top:
        chart_type_dict['regional'] = 'Top200'
    if crawl_viral:
        chart_type_dict['viral'] = 'Viral50'
        
    chart_interval_list = list()
    if crawl_daily:
        chart_interval_list.append('daily')
    if crawl_weekly:
        chart_interval_list.append('weekly')
    
    # 2. instantiates result lists
    result_data = []
    error_list = []
    
    print('----------------------------------------------------------------------')
    print('\nWEB CRAWLING LOG:\n\n')

    # 3. scrapes all available charts
    # 3.1. loops through chart types
    for chart_type, chart_name in chart_type_dict.items():
        
        chart_type_url = base_url + '/' + chart_type
        if select_regions_dict is None:
            chart_regions_dict = scrape_region_dict(chart_type_url)
        else:
            chart_regions_dict = select_regions_dict

        # 3.2. loops through chart regions
        for chart_region_abrv, chart_region_name in chart_regions_dict.items():

            # 3.3. loops through chart intervals
            for chart_interval in chart_interval_list:
                
                latest_charts_url = chart_type_url + '/' + chart_region_abrv + '/' + chart_interval

                try:
                    charts_dates_list = scrape_charts_dates(latest_charts_url, start_date, end_date)
                    
                except (http.client.IncompleteRead, urllib.error.HTTPError) as err:
                    error_list.append(handle_error(chart_date, chart_region_abrv, 
                                                   chart_name, np.nan , chart_date_url, err))
                    continue
                
                # 3.4. loops through all available chart dates
                for chart_date in charts_dates_list:

                    chart_date_url = latest_charts_url + '/' + chart_date.isoformat()

                    # 3.4.1. tries, then retries 3 times, to read the chart's html page
                    for attempt in range(1,4):
                        # 3.4.1.1. tries to read the url, and if successful, scrapes and appends its data
                        try:
                            chart_date_soup = get_soup(chart_date_url)
                            chart_date_data = scrape_chart(chart_date_soup, 
                                                           chart_name, 
                                                           chart_regions_dict[chart_region_abrv], 
                                                           chart_date)
                            result_data.append(chart_date_data)
                            print('Success: ', chart_date, 
                                  ' - ', chart_region_abrv, 
                                  ' - ', chart_name, 
                                  ' - ', chart_date_url)
                            break

                        # 3.4.1.2. cathces IncompleteRead exceptions, retrying the URL twice
                        except (http.client.IncompleteRead, urllib.error.HTTPError) as err:
                            error_list.append(handle_error(chart_date, chart_region_abrv, 
                                                           chart_name, attempt , chart_date_url, err))
                            continue

                    # 3.5. otherwise, if the loop falls through, skips this chart date
                    else:
                        error_list.append(handle_error(chart_date, chart_region_abrv, 
                                                       chart_name, -1 , chart_date_url, 'SKIPPED'))
                        continue

    print('\n----------------------------------------------------------------------')
    print('\n\tCOMPLETED: WEB CRAWLING/SCRAPING')
                        
    # 4. creates both the result and error pd.DataFrames from the accumulated list of data entries
    result_data_flat = [chart_entry for date_data in result_data for chart_entry in date_data]
    result_df_cols = ['Chart', 'Region' , 'Date', 'Position', 'Trend', 
                      'Title', 'Artist', 'Streams', 'Icon_URL', 'Spotify_URL', 'Spotify_ID']
    result_df = pd.DataFrame(result_data_flat, columns=result_df_cols)
    
    error_df_cols = ['Chart', 'Region', 'Date', 'Chart URL', 'Attempt', 'Error']
    error_df = pd.DataFrame(error_list, columns=error_df_cols)                 
    
    # 5. saves both the result and error pd.DataFrame as csv files  
    now_timestamp = get_timestamp_str()
    start_datestamp = get_datestamp_str(charts_dates_list[0])
    end_datestamp = get_datestamp_str(charts_dates_list[-1])
    
    result_df.to_csv(gen_csv_filepath('Result_', now_timestamp, start_datestamp, end_datestamp))
    error_df.to_csv(gen_csv_filepath('Errors_', now_timestamp, start_datestamp, end_datestamp))
    
    print('\n\tCOMPLETED: DATAFRAME/CSV CREATION')
    print('\n----------------------------------------------------------------------')
    gen_analysis_report(result_df, error_df)
    print('\n----------------------------------------------------------------------')
    
    # 6. returns the result pd.DataFrame
    return result_df

# %% [markdown]
# ---
# ## 3. Method Call

# %%
# WEB CRAWL CALL
# date_var1 = datetime.date(2017,1,1)
# date_var2 = datetime.date(2017,1,5)
# date_var3 = datetime.date(2019,11,12)

crawl_df = crawl_spotify_charts(
    start_date=None,
    end_date=None,
    select_regions_dict={'us':'United States'}, 
    crawl_top=True,
    crawl_daily=True)

crawl_df
# Out:
# ----------------------------------------------------------------------
#
# WEB CRAWLING LOG:
#
#
# Success:  2017-01-01  -  us  -  Top200  -  https://spotifycharts.com/regional/us/daily/2017-01-01
# Success:  2017-01-02  -  us  -  Top200  -  https://spotifycharts.com/regional/us/daily/2017-01-02
# Success:  2017-01-03  -  us  -  Top200  -  https://spotifycharts.com/regional/us/daily/2017-01-03
# Success:  2017-01-04  -  us  -  Top200  -  https://spotifycharts.com/regional/us/daily/2017-01-04
# Success:  2017-01-05  -  us  -  Top200  -  https://spotifycharts.com/regional/us/daily/2017-01-05
#
# ----------------------------------------------------------------------
#
# 	COMPLETED: WEB CRAWLING/SCRAPING
#
# 	COMPLETED: DATAFRAME/CSV CREATION
#
# ----------------------------------------------------------------------
#
# RESULT ANALYSIS
#
# -----
#
# RESULTS:
#
#                          Value
# Metric
# Num Rows                  1000
# Num Cols                    11
# Num Unique Dates             5
# Num Unique Charts            1
# Num Unique Regions           1
# Num Unique Positions       200
# Num Unique Trends            4
# Num Unique Titles          246
# Num Unique Artists         153
# Num Unique Icon_URLs       200
# Num Unique Spotify_URLs    253
#
# Num Rows==Dates?
#  – YES
#
# Num Titles==Spotify_URLs?
#  – NO: 246 ≠ 253
#
# Num Dates==Date Delta?
#  – NO: 5 ≠ 4
#
# -----
#
# ERRORS:
#
#                     Value
# Metric
# Num IncompleteRead      0
# Num HTTP                0
# Num Other               0
# Num Total Errors        0
#
# Num HTTP==Skips?
#  – YES
#
# Num Total==Sum?
#  – YES
#
# Min date: 2017-01-01
# Max date: 2017-01-05
#
# SKIPPED CHARTS:
#
#
#
# Empty DataFrame
# Columns: [Chart, Region, Date, Chart URL, Attempt, Error]
# Index: []
#
# ----------------------------------------------------------------------
#       Chart         Region        Date  Position Trend  \
# 0    Top200  United States  2017-01-01         1  Flat
# 1    Top200  United States  2017-01-01         2  Flat
# 2    Top200  United States  2017-01-01         3  Flat
# 3    Top200  United States  2017-01-01         4  Flat
# 4    Top200  United States  2017-01-01         5  Flat
# 5    Top200  United States  2017-01-01         6    Up
# 6    Top200  United States  2017-01-01         7    Up
# 7    Top200  United States  2017-01-01         8  Down
# 8    Top200  United States  2017-01-01         9    Up
# 9    Top200  United States  2017-01-01        10  Down
# 10   Top200  United States  2017-01-01        11  Flat
# 11   Top200  United States  2017-01-01        12    Up
# 12   Top200  United States  2017-01-01        13  Down
# 13   Top200  United States  2017-01-01        14    Up
# 14   Top200  United States  2017-01-01        15  Down
# 15   Top200  United States  2017-01-01        16    Up
# 16   Top200  United States  2017-01-01        17    Up
# 17   Top200  United States  2017-01-01        18  Down
# 18   Top200  United States  2017-01-01        19    Up
# 19   Top200  United States  2017-01-01        20  Flat
# 20   Top200  United States  2017-01-01        21    Up
# 21   Top200  United States  2017-01-01        22    Up
# 22   Top200  United States  2017-01-01        23  Down
# 23   Top200  United States  2017-01-01        24    Up
# 24   Top200  United States  2017-01-01        25  Down
# 25   Top200  United States  2017-01-01        26    Up
# 26   Top200  United States  2017-01-01        27  Down
# 27   Top200  United States  2017-01-01        28  Down
# 28   Top200  United States  2017-01-01        29    Up
# 29   Top200  United States  2017-01-01        30    Up
# ..      ...            ...         ...       ...   ...
# 970  Top200  United States  2017-01-05       171  Down
# 971  Top200  United States  2017-01-05       172  Down
# 972  Top200  United States  2017-01-05       173  Down
# 973  Top200  United States  2017-01-05       174    Up
# 974  Top200  United States  2017-01-05       175  Down
# 975  Top200  United States  2017-01-05       176    Up
# 976  Top200  United States  2017-01-05       177    Up
# 977  Top200  United States  2017-01-05       178    Up
# 978  Top200  United States  2017-01-05       179  Down
# 979  Top200  United States  2017-01-05       180  Flat
# 980  Top200  United States  2017-01-05       181  Down
# 981  Top200  United States  2017-01-05       182  Flat
# 982  Top200  United States  2017-01-05       183    Up
# 983  Top200  United States  2017-01-05       184    Up
# 984  Top200  United States  2017-01-05       185  Down
# 985  Top200  United States  2017-01-05       186  Down
# 986  Top200  United States  2017-01-05       187    Up
# 987  Top200  United States  2017-01-05       188  Down
# 988  Top200  United States  2017-01-05       189    Up
# 989  Top200  United States  2017-01-05       190  Down
# 990  Top200  United States  2017-01-05       191  Down
# 991  Top200  United States  2017-01-05       192  Down
# 992  Top200  United States  2017-01-05       193  Down
# 993  Top200  United States  2017-01-05       194    Up
# 994  Top200  United States  2017-01-05       195   New
# 995  Top200  United States  2017-01-05       196  Down
# 996  Top200  United States  2017-01-05       197    Up
# 997  Top200  United States  2017-01-05       198   New
# 998  Top200  United States  2017-01-05       199  Down
# 999  Top200  United States  2017-01-05       200   New
#
#                                                  Title               Artist  \
# 0                  Bad and Boujee (feat. Lil Uzi Vert)                Migos
# 1                                            Fake Love                Drake
# 2                                              Starboy           The Weeknd
# 3                                               Closer     The Chainsmokers
# 4                                        Black Beatles         Rae Sremmurd
# 5                          Broccoli (feat. Lil Yachty)                 DRAM
# 6                                            One Dance                Drake
# 7                                             Caroline                Aminé
# 8                                      Let Me Love You             DJ Snake
# 9                                          Bounce Back             Big Sean
# 10                                    I Feel It Coming           The Weeknd
# 11                                           24K Magic           Bruno Mars
# 12                    Bad Things (with Camila Cabello)    Machine Gun Kelly
# 13                                    X (feat. Future)            21 Savage
# 14   I Don’t Wanna Live Forever (Fifty Shades Darke...                 ZAYN
# 15                                    Don't Wanna Know             Maroon 5
# 16                Chill Bill (feat. J. Davi$ & Spooks)            Rob $tone
# 17                                             Deja Vu              J. Cole
# 18                                              OOOUUU            Young M.A
# 19                                       Party Monster           The Weeknd
# 20             No Problem (feat. Lil Wayne & 2 Chainz)    Chance the Rapper
# 21                                            No Heart            21 Savage
# 22                                            Starving     Hailee Steinfeld
# 23                                   Don't Let Me Down     The Chainsmokers
# 24                                        Side To Side        Ariana Grande
# 25                                    Treat You Better         Shawn Mendes
# 26                                 In the Name of Love        Martin Garrix
# 27                                            Sneakin’                Drake
# 28   CAN'T STOP THE FEELING! (Original Song from Dr...    Justin Timberlake
# 29                Work from Home (feat. Ty Dolla $ign)        Fifth Harmony
# ..                                                 ...                  ...
# 970                                    How Far I'll Go      Auli'i Cravalho
# 971                                            Oh Lord            MiC LOWRY
# 972                     Dynamite (feat. Pretty Sister)                Nause
# 973                                   'Till I Collapse               Eminem
# 974                   Taped up Heart (feat. Clara Mae)                KREAM
# 975           Lose Yourself - From "8 Mile" Soundtrack               Eminem
# 976                                           Location               Khalid
# 977                                           Antidote         Travis Scott
# 978                                    Uber Everywhere            MadeinTYO
# 979            Juke Jam (feat. Justin Bieber & Towkio)    Chance the Rapper
# 980                                     Foldin Clothes              J. Cole
# 981                                                LUV           Tory Lanez
# 982                                          Let It Go            James Bay
# 983                                             Middle             DJ Snake
# 984                                         Wet Dreamz              J. Cole
# 985                                           Miss You         James Hersey
# 986                                              Hello                Adele
# 987                                        Crazy Brazy             A$AP Mob
# 988                                     everybody dies              J. Cole
# 989                                             Castro             Yo Gotti
# 990                                           Unsteady        X Ambassadors
# 991                                            No Type         Rae Sremmurd
# 992                                      Really Really          Kevin Gates
# 993        Light It Up (feat. Nyla & Fuse ODG) - Remix          Major Lazer
# 994                                           My House             Flo Rida
# 995                               Versace on the Floor           Bruno Mars
# 996                                Death of a Bachelor  Panic! At The Disco
# 997                                       Skateboard P            MadeinTYO
# 998                                        Childs Play                Drake
# 999                                            Rap God               Eminem
#
#      Streams                                           Icon_URL  \
# 0    1371493  https://i.scdn.co/image/ab67616d0000485199a8ab...
# 1    1180074  https://i.scdn.co/image/6dfd956b9331fa9ea1f47e...
# 2    1064351  https://i.scdn.co/image/ab67616d000048510c8599...
# 3    1010492  https://i.scdn.co/image/ab67616d00004851495ce6...
# 4     874289  https://i.scdn.co/image/16293ab3b4f9301aeb5f41...
# 5     763259  https://i.scdn.co/image/ab67616d00004851f02a15...
# 6     753150  https://i.scdn.co/image/ab67616d00004851726abc...
# 7     714839  https://i.scdn.co/image/ab67616d00004851f79e6e...
# 8     690483  https://i.scdn.co/image/ab67616d000048515045de...
# 9     682688  https://i.scdn.co/image/695d0c097d8463ccc2c2b9...
# 10    651807  https://i.scdn.co/image/b3683184efeb899b2d1a02...
# 11    574974  https://i.scdn.co/image/ab67616d00004851232711...
# 12    567789  https://i.scdn.co/image/d5f976093a4dcbc5ea9d4c...
# 13    544620  https://i.scdn.co/image/ab67616d000048512dd1ac...
# 14    507450  https://i.scdn.co/image/ab67616d000048512ae921...
# 15    486364  https://i.scdn.co/image/ab67616d00004851eec191...
# 16    485127  https://i.scdn.co/image/ab67616d000048516f3e96...
# 17    478503  https://i.scdn.co/image/fff50a2874dae97e76d3a7...
# 18    456308  https://i.scdn.co/image/ab67616d0000485111042a...
# 19    456291  https://i.scdn.co/image/6aeaaebcbd861c8369b143...
# 20    449345  https://i.scdn.co/image/ab67616d00004851e71dd1...
# 21    447063  https://i.scdn.co/image/ab67616d000048512dd1ac...
# 22    446785  https://i.scdn.co/image/ab67616d00004851612495...
# 23    446177  https://i.scdn.co/image/ab67616d0000485108d87f...
# 24    440123  https://i.scdn.co/image/ab67616d000048517227f5...
# 25    438954  https://i.scdn.co/image/ab67616d00004851188e63...
# 26    435945  https://i.scdn.co/image/ab67616d00004851923db3...
# 27    419434  https://i.scdn.co/image/8b1f6991ae1192e214374d...
# 28    417329  https://i.scdn.co/image/ab67616d00004851ef3741...
# 29    405483  https://i.scdn.co/image/ab67616d00004851d03fa6...
# ..       ...                                                ...
# 970   159787  https://i.scdn.co/image/d7dd6ccce3d94aaa061d9e...
# 971   159564  https://i.scdn.co/image/ab67616d00004851d0b317...
# 972   159500  https://i.scdn.co/image/ab67616d0000485136434b...
# 973   159387  https://i.scdn.co/image/ab67616d00004851ccdb19...
# 974   159100  https://i.scdn.co/image/ab67616d000048519e4c02...
# 975   158827  https://i.scdn.co/image/36440dfd440d23086573d6...
# 976   158409  https://i.scdn.co/image/ab67616d00004851988ede...
# 977   156013  https://i.scdn.co/image/ab67616d00004851743317...
# 978   155799  https://i.scdn.co/image/ab67616d00004851da5e3b...
# 979   155724  https://i.scdn.co/image/ab67616d00004851e71dd1...
# 980   153990  https://i.scdn.co/image/fff50a2874dae97e76d3a7...
# 981   153370  https://i.scdn.co/image/31f9b64bda454305cb3c0f...
# 982   152658  https://i.scdn.co/image/abcbe01d6557c60388e976...
# 983   151933  https://i.scdn.co/image/ab67616d000048515045de...
# 984   151299  https://i.scdn.co/image/ab67616d000048516aca03...
# 985   151098  https://i.scdn.co/image/ab67616d00004851591d26...
# 986   150369  https://i.scdn.co/image/ab67616d000048514c3bbc...
# 987   150094  https://i.scdn.co/image/ab67616d0000485130eaf2...
# 988   149601  https://i.scdn.co/image/ccd3bf4beea7e1674f08b5...
# 989   148734  https://i.scdn.co/image/ab67616d00004851062b24...
# 990   148502  https://i.scdn.co/image/49174cd8d2128143eadb6f...
# 991   148238  https://i.scdn.co/image/ab7b10a577970824322b95...
# 992   148127  https://i.scdn.co/image/ab67616d000048519b78cd...
# 993   147655  https://i.scdn.co/image/ab67616d00004851751a2e...
# 994   145003  https://i.scdn.co/image/ab67616d000048517947bf...
# 995   144943  https://i.scdn.co/image/ab67616d00004851232711...
# 996   144546  https://i.scdn.co/image/ab67616d0000485123152d...
# 997   144479  https://i.scdn.co/image/ab67616d00004851094bcf...
# 998   143822  https://i.scdn.co/image/ec714b177b77eedd97bcc4...
# 999   142913  https://i.scdn.co/image/ab67616d000048514f2236...
#
#                                            Spotify_URL              Spotify_ID
# 0    https://open.spotify.com/track/4Km5HrUvYTaSUfi...  4Km5HrUvYTaSUfiSGPJeQR
# 1    https://open.spotify.com/track/343YBumqHu19cGo...  343YBumqHu19cGoGARUTsd
# 2    https://open.spotify.com/track/5aAx2yezTd8zXrk...  5aAx2yezTd8zXrkmtKl66Z
# 3    https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  7BKLCZ1jbUBVqRi2FVlTVw
# 4    https://open.spotify.com/track/6fujklziTHa8uoM...  6fujklziTHa8uoM5OQSfIo
# 5    https://open.spotify.com/track/7yyRTcZmCiyzzJl...  7yyRTcZmCiyzzJlNzGC9Ol
# 6    https://open.spotify.com/track/1xznGGDReH1oQq0...  1xznGGDReH1oQq0xzbwXa3
# 7    https://open.spotify.com/track/7FB8l7UA1HKqnuS...  7FB8l7UA1HKqnuSLjP9qDc
# 8    https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  4pdPtRcBmOSQDlJ3Fk945m
# 9    https://open.spotify.com/track/0SGkqnVQo9KPytS...  0SGkqnVQo9KPytSri1H6cF
# 10   https://open.spotify.com/track/5GXAXm5YOmYT0kL...  5GXAXm5YOmYT0kL5jHvYBt
# 11   https://open.spotify.com/track/6b8Be6ljOzmkOmF...  6b8Be6ljOzmkOmFslEb23P
# 12   https://open.spotify.com/track/1PSBzsahR2AKwLJ...  1PSBzsahR2AKwLJgx8ehBj
# 13   https://open.spotify.com/track/6fwdbPMwP1zVStm...  6fwdbPMwP1zVStm8FybmkO
# 14   https://open.spotify.com/track/3NdDpSvN911VPGi...  3NdDpSvN911VPGivFlV5d0
# 15   https://open.spotify.com/track/5MFzQMkrl1FOOng...  5MFzQMkrl1FOOng9tq6R9r
# 16   https://open.spotify.com/track/5uDASfU19gDxSjW...  5uDASfU19gDxSjW8cnCaBp
# 17   https://open.spotify.com/track/6I6NX6tjGsxFAsI...  6I6NX6tjGsxFAsIfGzY9lJ
# 18   https://open.spotify.com/track/7JYsArznYOjX2js...  7JYsArznYOjX2jsrT3UEnL
# 19   https://open.spotify.com/track/4F7A0DXBrmUAkp3...  4F7A0DXBrmUAkp32uenhZt
# 20   https://open.spotify.com/track/0v9Wz8o0BT8DU38...  0v9Wz8o0BT8DU38R4ddjeH
# 21   https://open.spotify.com/track/4gmmRb6bZJffOOi...  4gmmRb6bZJffOOiww1JGTO
# 22   https://open.spotify.com/track/1qOLh0tI7trd1zd...  1qOLh0tI7trd1zdDKxYZTe
# 23   https://open.spotify.com/track/0QsvXIfqM0zZoer...  0QsvXIfqM0zZoerQfsI9lm
# 24   https://open.spotify.com/track/4pLwZjInHj3SimI...  4pLwZjInHj3SimIyN9SnOz
# 25   https://open.spotify.com/track/4Hf7WnR761jpxPr...  4Hf7WnR761jpxPr5D46Bcd
# 26   https://open.spotify.com/track/04DwTuZ2VBdJCCC...  04DwTuZ2VBdJCCC5TROn7L
# 27   https://open.spotify.com/track/4ckuS4Nj4FZ7i3D...  4ckuS4Nj4FZ7i3Def3Br8W
# 28   https://open.spotify.com/track/6JV2JOEocMgcZxY...  6JV2JOEocMgcZxYSZelKcc
# 29   https://open.spotify.com/track/4tCtwWceOPWzenK...  4tCtwWceOPWzenK2HAIJSb
# ..                                                 ...                     ...
# 970  https://open.spotify.com/track/6mb6lVLNrcUgLnE...  6mb6lVLNrcUgLnEN8QnDJd
# 971  https://open.spotify.com/track/1sTUEdVO85YU8Ym...  1sTUEdVO85YU8Ymk2jeAls
# 972  https://open.spotify.com/track/2Ae5awwKvQpTBKQ...  2Ae5awwKvQpTBKQHr1TYCg
# 973  https://open.spotify.com/track/6yr8GiTHWvFfi4o...  6yr8GiTHWvFfi4o6Q5ebdT
# 974  https://open.spotify.com/track/26hcyzSE154xMZC...  26hcyzSE154xMZCbFdtInA
# 975  https://open.spotify.com/track/5Z01UMMf7V1o0Mz...  5Z01UMMf7V1o0MzF86s6WJ
# 976  https://open.spotify.com/track/152lZdxL1OR0ZMW...  152lZdxL1OR0ZMW6KquMif
# 977  https://open.spotify.com/track/1wHZx0LgzFHyeIZ...  1wHZx0LgzFHyeIZkUydNXq
# 978  https://open.spotify.com/track/7zBPzAjKAqQpcv8...  7zBPzAjKAqQpcv8F8GCq5s
# 979  https://open.spotify.com/track/3eze1OsZ1rqeXkK...  3eze1OsZ1rqeXkKStNfTmi
# 980  https://open.spotify.com/track/77IAeEz8LEchPN8...  77IAeEz8LEchPN8UNjaTJ2
# 981  https://open.spotify.com/track/16Ah4QqH4mgYVXq...  16Ah4QqH4mgYVXqfC4mdSd
# 982  https://open.spotify.com/track/13HVjjWUZFaWilh...  13HVjjWUZFaWilh2QUJKsP
# 983  https://open.spotify.com/track/4OZEu0Vwq0RB2LA...  4OZEu0Vwq0RB2LAq14v99n
# 984  https://open.spotify.com/track/6Ius4TC0L3cN74H...  6Ius4TC0L3cN74HT7ENE6e
# 985  https://open.spotify.com/track/7of1slAJIWrXxP8...  7of1slAJIWrXxP8ikAHxje
# 986  https://open.spotify.com/track/4sPmO7WMQUAf45k...  4sPmO7WMQUAf45kwMOtONw
# 987  https://open.spotify.com/track/59e7E2LMPZ2bhW5...  59e7E2LMPZ2bhW5G6aCwX8
# 988  https://open.spotify.com/track/1wIQtB3UQ1TfjNM...  1wIQtB3UQ1TfjNMZZqO6eh
# 989  https://open.spotify.com/track/0rHJxNaQRMGK6Y4...  0rHJxNaQRMGK6Y4TUx3xRO
# 990  https://open.spotify.com/track/7lGKEWMXVWWTt3X...  7lGKEWMXVWWTt3X71Bv44I
# 991  https://open.spotify.com/track/4scpF6J5uMBvoh6...  4scpF6J5uMBvoh6sFB7EL1
# 992  https://open.spotify.com/track/10I3CmmwT0BkOVh...  10I3CmmwT0BkOVhduDy53o
# 993  https://open.spotify.com/track/0L7loeTIg6akW84...  0L7loeTIg6akW84aEQZpCT
# 994  https://open.spotify.com/track/6Knv6wdA0luoMUu...  6Knv6wdA0luoMUuuoYi2i1
# 995  https://open.spotify.com/track/0kN8xEmgMW9mh7U...  0kN8xEmgMW9mh7UmDYHlJP
# 996  https://open.spotify.com/track/1BECwm5qkaBwlbf...  1BECwm5qkaBwlbfo4kpYx8
# 997  https://open.spotify.com/track/4qdgv45EPcQqpQ0...  4qdgv45EPcQqpQ08tF34f8
# 998  https://open.spotify.com/track/3NxAG2ni1lLa8RK...  3NxAG2ni1lLa8RKL6a0INc
# 999  https://open.spotify.com/track/6sDQ4uiWw9OdVrC...  6sDQ4uiWw9OdVrCXFLSlZt
#
# [1000 rows x 11 columns]

# %% [markdown]
# ---
# ## 4. Testing

# %% [markdown]
# ### 4.1. Test Variables

# %%
# oneday_delta= datetime.timedelta(days = 1)

# jan2017_strt = datetime.date(2017,1,1)
# jan2017_5 = datetime.date(2017,1,5)
# feb2017_strt = datetime.date(2017,2,1)
# mar2017_strt = datetime.date(2017,3,1)

# jan2017_end = feb2017_strt - oneday_delta
# feb2017_end = mar2017_strt - oneday_delta

# %% [markdown]
# ### 4.2. Test Method

# %%
# # Test Call:
# crawl_spotify_charts(start_date = jan2017_strt, 
#                      end_date = mar2017_strt,
#                      select_regions_dict={'us':'United States'}, 
#                      crawl_top=True,
#                      crawl_daily=True)
