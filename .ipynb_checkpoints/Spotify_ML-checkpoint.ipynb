# %%
import os

import pandas as pd
import numpy as np
import csv

import dateutil.parser
import datetime
import sys

import spotipy
import spotipy.util

import sklearn

# %%
def get_newest_dirpath(data_dirpath):
    dir_contents = [d for d in os.listdir(data_dirpath) if d.startswith('D-')]
    dir_contents.sort(reverse = True)
    dir_name = dir_contents[0]
    return os.path.join(data_dirpath, dir_name)

def get_newst_dataset():
    pull_dirpath = get_newest_dirpath('./data')
    data_filepath = [d for d in os.listdir(pull_dirpath) if d.startswith('ml_dataset')][0]
    spotify_df = pd.read_csv(os.path.join(pull_dirpath, data_filepath), index_col=0)
    return spotify_df

# %%
get_newst_dataset()
# Out:
#                   Spotify_ID  \
# 0     4Km5HrUvYTaSUfiSGPJeQR
# 1     343YBumqHu19cGoGARUTsd
# 2     5aAx2yezTd8zXrkmtKl66Z
# 3     7BKLCZ1jbUBVqRi2FVlTVw
# 4     6fujklziTHa8uoM5OQSfIo
# 5     7yyRTcZmCiyzzJlNzGC9Ol
# 6     1xznGGDReH1oQq0xzbwXa3
# 7     7FB8l7UA1HKqnuSLjP9qDc
# 8     4pdPtRcBmOSQDlJ3Fk945m
# 9     0SGkqnVQo9KPytSri1H6cF
# 10    5GXAXm5YOmYT0kL5jHvYBt
# 11    6b8Be6ljOzmkOmFslEb23P
# 12    1PSBzsahR2AKwLJgx8ehBj
# 13    6fwdbPMwP1zVStm8FybmkO
# 14    3NdDpSvN911VPGivFlV5d0
# 15    5MFzQMkrl1FOOng9tq6R9r
# 16    5uDASfU19gDxSjW8cnCaBp
# 17    6I6NX6tjGsxFAsIfGzY9lJ
# 18    7JYsArznYOjX2jsrT3UEnL
# 19    4F7A0DXBrmUAkp32uenhZt
# 20    0v9Wz8o0BT8DU38R4ddjeH
# 21    4gmmRb6bZJffOOiww1JGTO
# 22    1qOLh0tI7trd1zdDKxYZTe
# 23    0QsvXIfqM0zZoerQfsI9lm
# 24    4pLwZjInHj3SimIyN9SnOz
# 25    4Hf7WnR761jpxPr5D46Bcd
# 26    04DwTuZ2VBdJCCC5TROn7L
# 27    4ckuS4Nj4FZ7i3Def3Br8W
# 28    6JV2JOEocMgcZxYSZelKcc
# 29    4tCtwWceOPWzenK2HAIJSb
# ...                      ...
# ...

# %%
# 3.0. Data Loading
from sklearn.model_selection import train_test_split
spotify_df = get_newst_dataset()

ids = spotify_df.iloc[:, 2]
features = spotify_df.iloc[:, 3:-1]
target = spotify_df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=3000)

# %%
# 3.1. Data Wrangling
from sklearn.feature_selection import SelectFromModel
from sklearn.tree import DecisionTreeClassifier

select = SelectFromModel(DecisionTreeClassifier(random_state = 3000), threshold = "median")
select.fit(X_train, y_train)

#transform training and testing sets so only the selected features are retained
X_train_selected = select.transform(X_train)
X_test_selected = select.transform(X_test)

model = LinearRegression().fit(X=X_train, y=y_train)

print("Original results:")
print("\tR-squared value for training set: ", r2_score(y_train, model.predict(X_train)))
print("\tR-squared value for testing set: ", r2_score(y_test, model.predict(X_test)))


model = LinearRegression().fit(X=X_train_selected, y=y_train)

print("With selected features:")
print("\tR-squared value for training set: ", r2_score(y_train, model.predict(X_train_selected)))
print("\tR-squared value for testing set: ", r2_score(y_test, model.predict(X_test_selected)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fe0346e21369> in <module>
#       1 # 3.1. Feature Selection
#       2
# ----> 3 select.fit(X_train, y_train)
#       4
#       5 #transform training and testing sets so only the selected features are retained
#
# NameError: name 'select' is not defined

# %%
# 3.3. Model Construction

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

classifiers = {
    'k-Nearest Neighbor' : KNeighborsClassifier(),
    'Support Vector Machine' : SVC(gamma='auto'),
    'Gaussian Naive Bayes' : GaussianNB(),
    'Decision Tree' : DecisionTreeClassifier()
}

# %%
# from sklearn.metrics import r2_score
# def regressors_percentage_split():
#     for regressor_name, regressor_obj in estimators.items():
#         fitted_regressor = regressor_obj.fit(X_train, y_train)
#         r2_train_val = r2_score(y_train, fitted_regressor.predict(X_train))
#         r2_test_val = r2_score(y_test, fitted_regressor.predict(X_test))
#         print(regressor_name + ':')
#         print('\tR-squared value for training set: ', r2_train_val)
#         print('\tR-squared value for testing set: ', r2_test_val, '\n')

# %%
feature_vars = [
    'album_type', # nominal 
    'total_tracks',
    'duration_ms', # continuous 
    'explicit', 
    'track_number', 
    'mode', 
    'time_signature',
    'danceability', # continuous 
    'energy', # continuous 
    'key', 
    'loudness', # continuous 
    'speechiness', # continuous 
    'acousticness', # continuous 
    'instrumentalness', # continuous 
    'liveness', # continuous 
    'valence', # continuous 
    'tempo' # continuous 
]

target_vars = [
    'max_chart_rank',
    'max_daily_streams'
]
